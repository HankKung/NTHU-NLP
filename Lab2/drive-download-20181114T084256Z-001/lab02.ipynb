# %%
# pip install wikipedia
# nltk.download("wordnet")
import os
import wikipedia
import nltk
from collections import defaultdict
from nltk.corpus import wordnet as wn
# downlaod wordnet 3.0
#nltk.download("wordnet")

# %% [markdown]
# # 9 words 54 synsets to find wiki pages, use pos="n" only.

# %%
# Load synsets
target_synsets = []
for line in open("/Users/7ckung/Desktop/Lab2/lab02_input.txt"):
    word, synset, offset = line.strip().split("\t")
    target_synsets.append((word, wn.synset_from_pos_and_offset('n', int(offset))))
            
print("The amount of target synsets :%d" %(len(target_synsets)))
# Out:
# The amount of target synsets :54

# %%
wn_ec ={}
for line in open("/Users/7ckung/Desktop/Lab2/wn.ec.noun.txt"):
    offset = line.strip().split("\t")[1]
    ch = line.strip().split("\t")[2]
    if offset not in wn_ec:
        wn_ec[offset] = ch
wn_ec
# Out:
# {'7125096': '詛咒',
#  '7126228': '助詞|虛字',
#  '14123044': '風疹|痲疹',
#  '9902017': '牧場主人|養牛人',
#  '3259505': '住家|住屋',
#  '11660537': '紅豆杉亞綱',
#  '15279480': '加速度',
#  '13098515': '維管射線',
#  '1629093': '蠑螈屬',
#  '5559256': '臀部|屁股',
#  '2523750': '黑線鱈屬',
#  '8983105': '華沙|波瀾首都',
#  '9250016': '科羅拉多河',
#  '9249418': '科羅拉多河',
#  '9067277': '科羅拉多',
#  '14369408': '呼吸暫停|窒息',
#  '8717059': '金邊',
#  '10270628': '獨來獨往的人|獨行俠',
#  '1615703': '歐洲東南部與中亞',
#  '13749894': '七十',
#  '1413188': '鼓藻科',
#  '13622209': '英制加侖|加侖',
#  '12590232': '油棕樹|油椰',
#  '4398497': '一種小餐館|喫茶店|茶室|茶館',
#  '300037': '背背包騎車',
#  '324056': '靜脈注射|輸血',
#  '13363056': '信託基金',
#  '3826762': '耐絞寧|三硝酸甘油酯|耐較嚀',
#  '7653394': '切下的肉',
#  '9037133': '東加|東加王國|東加群島',
#  '13598715': '原子序數|原子序',
#  '8229275': '西洋棋俱樂部',
#  '11700676': '蠟梅科雙子葉植物|夏蠟梅屬',
#  '2684515': '金屬飾物',
#  '2684649': '金屬小箍',
#  '346296': '換方向',
#  '3225777': '矩陣式打印機',
#  '8675967': '市區',
#  '7821260': '香車葉草',
#  '12665271': '香車葉草',
#  '14391480': '單向憂鬱症',
#  '5668581': '中世紀典雅愛情行為規範',
#  '5999455': '後設知識|後設性知識',
#  '11827169': '岡羊栖菜屬',
#  '6933279': '西緬|孟加拉及東印所說的語言',
#  '5491993': '大腦',
#  '3441112': '手套|手套',
#  '2885462': '拳擊手套',
#  '2800213': '棒球手套',
#  '12344131': '待宵草屬',
#  '7927197': '汽水|不含酒精清涼飲料',
#  '729919': '例題',
#  '624738': '體操|運動',
#  '947128': '利用|使用',
#  '7454452': '典禮|儀式',
#  '894552': '演算|練習|演習',
#  '10306004': '醫事研究人員',
#  '9014470': '科夫諾',
#  '6674947': '簡介|大綱|學校的入學簡介',
#  '6146760': '舊石器時代的人種誌',
#  '9686146': '祆教徒',
#  '2038617': '燕科',
#  '126584': '擊球|打擊',
#  '14750122': '已烯雌酚',
#  '4853361': '邪惡|卑鄙|道德敗壞',
#  '10209616': '工具|傀儡',
#  '13350875': '典當物|押頭|抵押物',
#  '3901750': '兵|卒',
#  '1111236': '典當',
#  '7688265': '玉米烤餅',
#  '5979454': '魅力|魔法',
#  '12965463': '麥角菌屬',
#  '6050901': '婦科學|婦科醫學',
#  '12831535': '金魚花|一種熱帶植物|有鋸齒狀的厚葉|獨生或串生的黃到紅花|多為其花朵和觀賞用的葉片而種',
#  '7886317': '卡瓦酒',
#  '13627516': '千位元組',
#  '13750844': '千',
#  '13714756': '開',
#  '14650807': '鉀',
#  '2354320': '穴居沙龜',
#  '15182189': '新年|元旦',
#  '1072565': '滿足',
#  '9825750': '修車技工|修車工人',
#  '14252184': '生殖細胞瘤|精細胞瘤',
#  '9930772': '男裝零售商|衣商',
#  '4141076': '薩克斯風|薩克斯管',
#  '13505843': '流淚',
#  '2120997': '貓科動物|貓',
#  '11606846': '柯連樹',
#  '9711754': '阿卡狄亞人',
#  '11117307': '老子',
#  '15208333': '恆星日',
#  '6877742': '噘嘴',
#  '623670': '職務代理人',
#  '10604180': '身高六呎的人',
#  '6558893': '罰單',
#  '11732567': '飛燕草',
#  '4829922': '寬大|厚道',
#  '4491135': '王牌',
#  '3306385': '快車',
#  '9079505': '夏威夷島',
#  '14138364': '流行性腦膜炎',
#  '7627931': '發酵麵糰',
#  '2191449': '麗蠅科',
#  '2185481': '寄生蟲',
#  '13497784': '感應生熱',
#  '8075388': '同業|團體|會',
#  '9381242': '露出地面的部分|露頭|一堆露出於地面上的岩',
#  '8498888': '小行星帶',
#  '4693384': '凹痕',
#  '11413661': '變少',
#  '13904843': '凹痕',
#  '13148602': '胡椒目',
#  '3509025': '暖氣',
#  '2234848': '蜚蠊',
#  '14518820': '水污染',
#  '3019198': '可將下顎吊上的棍子',
#  '6524454': '維修合約',
#  '2874214': '亭子|亭室',
#  '2874086': '攤子|攤位',
#  '2873839': '隔間',
#  '13733979': '被乘數',
#  '13745086': '八',
#  '2102806': '美洲水獚',
#  '6616806': '記錄影片',
#  '12342498': '柳蘭|柳草',
#  '4206695': '彈孔',
#  '3425595': '瓦斯爐|煤氣爐',
#  '5480076': '迷走神經',
#  '10823199': '阿姆斯壯',
#  '10654015': '速記員',
#  '6810238': '八進制計數制|八進位數字系統',
#  '13747989': '第十九',
#  '11821929': '南非肉質無莖植物|葉呈灰綠色|質地紋路像花崗岩',
#  '1890144': '北美東部鼴鼠',
#  '3875088': '草薦|草褥',
#  '13732295': '單分數',
#  '10182499': '戶長|屋主',
#  '10704712': '德克薩斯州的騎警',
#  '9970699': '同國人|同胞',
#  '1861465': '哺乳類',
#  '12455787': '火炎花屬',
#  '2176611': '叩頭蟲屬',
#  '3579699': '夾層',
#  '12432808': '洋蔥',
#  '6628663': '精神花束',
#  '12967504': '柔膜菌科',
#  '7547674': '輕視|藐視',
#  '5567604': '中指',
#  '3272940': '電攪拌器',
#  '9711009': '愛奧尼亞人',
#  '8294581': '人民陣線',
#  '5551711': '胸肌',
#  '13377899': '本地匯票',
#  '1880937': '結趾科',
#  '14709706': '酒精',
#  '9995829': '餐桌上的健談者',
#  '10809857': '阿古巴力',
#  '8567235': '環境',
#  '2432291': '維吉尼亞鹿',
#  '12197211': '可樂果屬',
#  '7927931': '可樂',
#  '3642806': '筆記型電腦|膝上型電腦',
#  '12393269': '苧麻纖維|苧麻',
#  '1634522': '斑泥螈',
#  '1581166': '灰噪鴉',
#  '9170294': '喀拉哈里沙漠',
#  '3136254': '挖礦石鑽',
#  '380083': '混合',
#  '8240633': '同好',
#  '8366753': '經濟組織|經濟',
#  '14364566': '繭|老繭',
#  '14363785': '瘉合組織',
#  '13088688': '癒合組織',
#  '8978667': '巴拉圭首都',
#  '15127165': '二疊紀',
#  '8801678': '意大利|義大利',
#  '2662993': '鰈魚',
#  '1669068': '盒龜屬',
#  '2270473': '衣魚屬',
#  '14321953': '發疹|出疹',
#  '9512692': '奈夫提斯',
#  '6726158': '宣言|宣佈|發佈',
#  '7462547': '有獎比賽',
#  '7045637': '固定音形',
#  '1400391': '黃藻',
#  '12158798': '南瓜藤|南瓜屬植物',
#  '114095': '擠|撞|推',
#  '4383015': '準距計|視距儀',
#  '11091706': '約瑟夫|聖母瑪利亞的丈夫',
#  '11091863': '約瑟|約瑟',
#  '1426314': '肌芽胞蟲目|肉胞子蟲目',
#  '12397864': '蛇麻|大麻',
#  '9778392': '尤指政府或警方雇用的',
#  '12277334': '美國中部橡樹',
#  '13547677': '還原',
#  '7568502': '麥片|燕麥片',
#  '5372924': '舌靜脈',
#  '12955191': '莎草蕨屬',
#  '6367571': '述實散文|非小說',
#  '2407959': '水牛',
#  '14379130': '心理健康',
#  '2354470': '美西囊地鼠屬',
#  '12769663': '省沽油屬|省沽油科的一屬小型喬木或灌木',
#  '7614004': '水果奶油布丁',
#  '7018824': '羊人劇',
#  '6679726': '珂羅版',
#  '14873344': '蟻酸',
#  '14630363': '氫氧化鋇',
#  '13915113': '四面體',
#  '13982357': '意見不一致|意見不同|意見不相投',
#  '7181546': '爭論|不和|意見不合',
#  '5522456': '陰唇',
#  '6489190': '榮譽名冊|優秀學生榜|榮譽榜',
#  '8766571': '在瑞典東南部|倫德',
#  '4126373': '保險鎖',
#  '4126244': '安全鎖',
#  '12089320': '野山藥',
#  '4968749': '翡翠色',
#  '702659': '相互抑制治療法',
#  '10713254': '美國財政部特派員或特別調查員',
#  '10421753': '藥物學家|藥理學家',
#  '8989697': '法屬波利尼西亞群島',
#  '2009620': '大白鷺屬',
#  '11880032': '菜油',
#  '5667086': '彩色印片法|彩色電影|攝影法',
#  '4132985': '俄國煮茶的銅壺|茶炊|金屬茶炊',
#  '3232815': '塞子|排水塞',
#  '2274516': '蛺蝶科',
#  '13366137': '便利設施',
#  '3909516': '擺鐘',
#  '3415868': '套式軌道的套迭處',
#  '7187996': '乞討|乞食',
#  '7852532': '巴伐利亞藍乳酪',
#  '10792178': '煩惱|擔憂',
#  '7458099': '直到最後才知結果的競',
#  '6621681': '懸疑故事',
#  '1779629': '恙蟲',
#  '13774115': '微量|一點',
#  '11962108': '紫錐花屬',
#  '9573966': '朱比特',
#  '9322454': '木星',
#  '12269241': '指多種美國常綠櫟樹',
#  '1809752': '麝雉',
#  '1709484': '雷龍',
#  '14405225': '興高采烈|得意洋洋',
#  '7527656': '振奮|興高采烈|得意洋洋',
#  '13893310': '磁偏角|磁北和正北差的角度',
#  '13588233': '音量係數',
#  '5703070': '看著時鐘等下班',
#  '3232676': '碗盤滴乾板',
#  '14335761': '輸尿管尿液回流',
#  '12857204': '薑味草',
#  '12366313': '書帶木',
#  '3869389': '土黴素',
#  '12104501': '牧草',
#  '7801091': '牧場|青草',
#  '13252395': '西語系國家的莊園',
#  '3474352': '莊園住宅',
#  '2441723': '鼬屬',
#  '10710171': '宗教儀式中捧香爐的人|捧香爐的人',
#  '3191776': '二後座的老式車子的第三個座位',
#  '2335231': '河狸鼠',
#  '5898171': '幻影|幽魂',
#  '9976917': '怪人',
#  '2276355': '紅紋蝶',
#  '3888998': '平行輸出入埠',
#  '14653596': '釤',
#  '12030479': '包括北美到墨西哥的一種草本植物或亞灌木的植物屬',
#  '9810983': '畫商',
#  '14452294': '超過',
#  '5118437': '過剩|過量|多餘',
#  '5119714': '盈餘|過剩|過多',
#  '1073655': '過度|過份',
#  '6448868': '海姆斯－杜埃版聖經|Rheims-Douay 版聖經',
#  '9438212': '沼澤',
#  '9438313': '泥沼|泥坑',
#  '9438055': '蛻皮|脫皮',
#  '12587686': '椰子屬',
#  '5939636': '幻想|錯覺',
#  '3668642': '外貌|外表|相片',
#  '4677952': '外貌',
#  '1707294': '大嘴恐龍',
#  '12541805': '歐洲多年生豆科植物|有粉紅或紫色交雜的花朵|有時種植來做秣或綠肥',
#  '12016434': '北美東部一種有奶油色白花的植物',
#  '7154243': '眾所周知|自明之理',
#  '8113073': '生意人',
#  '4690769': '華美|俗麗的美',
#  '4818700': '粗俗|花俏',
#  '15222369': '施洗約翰節前夕',
#  '5165028': '不明智|不得體|不可取',
#  '8231499': '大聯盟',
#  '3344393': '救火船|消防艇',
#  '4969242': '蒼天|天藍色|淡青色',
#  '199130': '改變',
#  '4243251': '賣成衣的商店',
#  '9543748': '小妖精|小鬼',
#  '3523288': '壁爐兩側的鍋架',
#  '9540739': '棕仙|小精靈',
#  '3523398': '裁齒工具',
#  '8109772': '單型',
#  '3784139': '單字鑄排機',
#  '2565324': '黑鱸|大嘴鱸',
#  '7777735': '大嘴鱸',
#  '1377906': '黏液菌目',
#  '13414310': '支票簿',
#  '10488309': '靈媒|巫師|通靈的人',
#  '7473441': '勝利|勝戰|凱旋',
#  '7528097': '勝利|大勝',
#  '2571810': '彩色大眼魚',
#  '2474282': '梭羅人',
#  '4391158': '穿刺器|穿刺',
#  '125436': '輕撫',
#  '4559451': '龍頭|飲水嘴|水龍頭|栓子',
#  '7410021': '輕擊',
#  '7388987': '輕拍聲',
#  '4390977': '塞子|桶子的活嘴|栓子',
#  '4391276': '金屬片',
#  '10533983': '叫喊者',
#  '1044983': '重視語言',
#  '12433769': '點頭',
#  '4010057': '拖曳用的鉤索',
#  '14198829': '維生素過多症',
#  '7391079': '咚咚聲|砰砰聲',
#  '4005090': '版畫店|印刷店',
#  '3789171': '電影攝影機',
#  '3556281': '止痛退燒藥',
#  '7549716': '嫉妒',
#  '758335': '嫉妒心|羨慕|妒意',
#  '14068177': '胰島素休克',
#  '2803129': '淺浮雕',
#  '5350453': '腰動脈',
#  '11798270': '矮菝契草',
#  '10293590': '女侯爵',
#  '3723153': '入口敞篷',
#  '15135434': '時下|目前|當前',
#  '10354754': '腦神經外科醫生',
#  '9927305': '洗衣店工人',
#  '13178500': '水龍骨科一屬附生蕨類',
#  '14820933': '彩色美術紙',
#  '1617443': '鬍鷲|髭兀鷹',
#  '497536': '補抽進的牌|補抽的牌',
#  '13610815': '吸音計算單位|吸音量單位',
#  '2855253': '吹矢槍|吹箭筒',
#  '2855560': '吹管',
#  '14731799': '血清蛋白素',
#  '11355669': '烏斐拉',
#  '15006012': '粗灰泥|外牆所塗刷之粗面',
#  '4112921': '粗工|毛坯',
#  '1943899': '海螺|貝殼',
#  '12323820': '使君子屬',
#  '14395955': '未老痴呆',
#  '5771836': '建構|構成',
#  '13647888': '重量單位',
#  '12905655': '番茄屬',
#  '10389398': '所有人|所有者',
#  '10388924': '業主|所有人',
#  '10716005': '折磨別人的人|令人傷腦筋的人',
#  '4456276': '袖幕',
#  '13267014': '補助金|補助|津貼',
#  '11954345': '北美薊花',
#  '856342': '雜亂|濫交',
#  '9575701': '伊比米修斯',
#  '1063350': '支支吾吾|口吃',
#  '5699434': '猶豫的狀態|遲疑|躊躇',
#  '4645943': '不情願|勉強|不願',
#  '6321702': '述詞',
#  '6319029': '形容詞|形容名詞的字',
#  '15135536': '生理時鐘',
#  '10780185': '守門員',
#  '2626590': '金槍魚屬',
#  '511676': '酒神節',
#  '511212': '放蕩|放縱',
#  '3632963': '化妝室|女廁所|女洗手間',
#  '14296579': '脊椎環節軟骨脫位',
#  '9558177': '拉丁史詩的黛朵女王',
#  '1599741': '美國中部的伯勞',
#  '2820210': '被褥|鋪蓋|寢具',
#  '1371928': '傷瘤病毒',
#  '5162807': '麻煩之事',
#  '4722715': '困難|不便',
#  '14446878': '不愉快|不舒服',
#  '4711435': '憂慮|不便',
#  '1046441': '動物崇拜',
#  '1790304': '美國原產普里茅斯品種的雞',
#  '9099098': '普里茅斯岩石',
#  '12573474': '黃豌豆',
#  '13724838': '公斤|公斤',
#  '3262349': '耳飾|耳環',
#  '4436542': '附有小鈴的手鼓',
#  '14956661': '黏糊糊的污物',
#  '7432119': '滲出',
#  '3397532': '荷葉邊|縐邊|飾邊',
#  '1631175': '太平洋蠑螈',
#  '4589325': '吊窗錘箱|花盆箱',
#  '1294127': '薩拉托加戰役',
#  '5758548': '森林知識|山林生活技能|山林知識',
#  '5644423': '木藝|木工|木工術',
#  '1834702': '夜鷹目',
#  '14010636': '暫停|中止',
#  '4366116': '避震系統',
#  '1017701': '懸擺|懸盪',
#  '14591091': '懸浮液|懸浮物|懸浮體',
#  '7368256': '暫時緩解',
#  '209132': '暫時剝奪',
#  '15271008': '暫停|中斷',
#  '10309614': '外籍傭兵',
#  '848466': '姦情|私通|通姦',
#  '14896018': '芳香樹脂|礦樹膠|硬樹脂',
#  '14766265': '柯巴脂|芳香樹脂',
#  '5340599': '視網膜中央動脈',
#  '1140193': '鑑定',
#  '522537': '表露|顯露',
#  '5043973': '飽受風霜|暴露',
#  '5934123': '朝向|方位',
#  '3925226': '相片|照片',
#  '204659': '遺棄',
#  '14543931': '暴露',
#  '13640206': '感光度',
#  '7215377': '揭露|揭發',
#  '157463': '曝露',
#  '907340': '曝光',
#  '12096089': '北美一種常見的黃花植物',
#  '13032923': '鐘型龍葵',
#  '12491017': '羊蹄甲',
#  '8664443': '處|點|地點',
#  '1936671': '海蚯蚓|沙虫蜀',
#  '13693641': '塞普勒斯鎊',
#  '8372299': '一部分',
#  '13737089': '一半',
#  '1592084': '山雀',
#  '8391953': '英國地方自衛隊',
#  '2830596': '苯集德靈',
#  '536120': '兩步圓舞|兩步舞|兩步滑行',
#  '11334003': '黑鬍子',
#  '8524404': '中心|中心點',
#  '5556595': '肚臍|臍',
#  '4975340': '色度|飽和度|濃度',
#  '5193338': '生動',
#  '9805475': '建築設計師',
#  '5647643': '笨拙',
#  '2023664': '屬',
#  '1665541': '棱龜|革龜|稜皮龜',
#  '7055805': '捷格舞曲',
#  '538991': '基格舞|捷格舞',
#  '2396014': '未閹割的雄豬',
#  '2396427': '野豬',
#  '12078954': '獨蒜蘭屬',
#  '3246933': '活動翻板桌',
#  '7112942': '子音系統',
#  '3273913': '電冰箱|冰箱',
#  '10954966': '艾森豪',
#  '6357632': '循環重複檢驗',
#  '5691689': '鐵幕|指原蘇聯和東歐等共產國家對西方民主各國嚴格隔離|封閉的屏障',
#  '2203152': '蠓|蚊',
#  '11865574': '南美濱海檳榔樹',
#  '2425532': '印度大羚羊',
#  '14279099': '流膠症|流膠現象',
#  '14278953': '流膠症',
#  '563494': '籃球賽',
#  '12387201': '菫菜屬',
#  '6141962': '社群互動',
#  '4579986': '白棋',
#  '3357081': '長褲',
#  '9478355': '白河|注入美國密西西比河',
#  '9638875': '白人',
#  '4960729': '白色',
#  '13146583': '索維農葡萄',
#  '4064747': '唱片封套',
#  '2791894': '佛羅拉',
#  '12556793': '普通豆類植物',
#  '7726796': '普通豆類',
#  '2183857': '蝨子|為哺乳類的寄生蟲',
#  '6109972': '孟德爾主義|孟德爾遺傳學說|孟德爾遺傳學',
#  '9167505': '辛巴威首都|索爾玆伯里市',
#  '8539072': '鬧區|商業區',
#  '4876985': '忠實|忠貞|忠誠',
#  '4804306': '傳真性|逼真',
#  '12423565': '百合科植物',
#  '5869407': '潛移默化|影響力',
#  '14934031': '酵母|酵素',
#  '3673594': '塗敷劑|治筋骨的塗敷藥',
#  '14500567': '雜亂|混亂',
#  '736219': '違法|犯罪',
#  '11890150': '大青|板藍根',
#  '1749244': '非洲眼鏡蛇|唾蛇',
#  '7988716': '兩相貌神似的人|像孿生兄弟似的',
#  '7293391': '公平的交易',
#  '13770416': '一甜點匙之量',
#  '12651611': '梨樹',
#  '12415272': '美國東南部的鳶尾屬植物|似變色鳶尾',
#  '10670668': '贊同者',
#  '10057271': '轉讓人',
#  '3891664': '特等車廂',
#  '12386039': '柳科',
#  '9480959': '蚯蚓糞',
#  '14855512': '蚯蚓糞',
#  '9609561': '逮捕者|擄掠者|捕捉者',
#  '6583645': '輸入常式',
#  '2201497': '瘧蚊',
#  '2104029': '庫伐茲匈牙利白犬',
#  '5602548': '額頭',
#  '5313535': '眉毛|眉',
#  '8584787': '坡頂|峭壁|陡坡',
#  '1965747': '海扇蛤科|扇貝科',
#  '10409011': '乞丐|貧民|窮鬼',
#  '6347225': '逐字翻譯|翻譯本',
#  '3131574': '嬰兒床|小兒搖籃',
#  '491901': '克里比其牌戲',
#  '1222859': '譏諷|辱罵|嘲諷|嘲弄',
#  '7923176': '浮有冰淇淋的沙士飲料',
#  '2422561': '高角羚屬|黑斑羚屬',
#  '13996719': '壓制|壓迫',
#  '7538674': '壓迫感',
#  '421047': '壓制|壓迫',
#  '203753': '避免|迴避|取消',
#  '13806140': '完成體動詞',
#  '2661017': '比目魚',
#  '13277179': '費用支出|運作的費用|屬於經常的開支',
#  '3961828': '擺放裝飾器皿的壁架',
#  '15165637': '進餐時間',
#  '12695975': '楝樹',
#  '9155692': '貝克理市',
#  '1588858': '刺鷯科的一屬',
#  '4164199': '最上層包廂|上層包廂',
#  '6052165': '免疫病理學',
#  '8809749': '皮得蒙|皮得蒙高原',
#  '9052100': '皮埃蒙特山麓高原|皮埃蒙特區',
#  '2245592': '同翅目',
#  '13339189': '死後償還借據',
#  '2428653': '越羚屬',
#  '1992773': '片腳類動物',
#  '7848196': '奶泡',
#  '4095342': '鉚釘',
#  '3626115': '瘤|節',
#  '6950400': '蘇格蘭低地方言',
#  '2648916': '十線六線魚',
#  '12821505': '維吉尼亞風鈴草',
#  '6509902': '主檔',
#  '3055418': '女用無帶的皮包',
#  '12717914': '番苦木科裡一小屬南非熱帶喬木或灌木',
#  '13111504': '殘株',
#  '11953038': '菊苣',
#  '7730855': '菊苣之葉',
#  '11953610': '菊苣根製成之粉末',
#  '7731284': '菊苣',
#  '3863442': '長針',
#  '11621950': '膠冷杉|膠樅',
#  '4271371': '槍尖|矛頭',
#  '1358259': '藍藻綱',
#  '856733': '好色|縱慾',
#  '12953712': '絨紫萁',
#  '8547143': '郡政府所在地',
#  '4240434': '一種摩擦離合器',
#  '11868814': '十字花科植物',
#  '7476623': '慘敗',
#  '11454953': '冰溶導致的洪水',
#  '7365432': '崩潰',
#  '2296150': '牧草夜蛾屬',
#  '2268443': '蜻蜓',
#  '3162556': '繡針',
#  '5000537': '超過重量|超重',
#  '10327002': '回教徒',
#  '12755387': '楓樹',
#  '11522730': '下降氣流',
#  '3413428': '賭場',
#  '12623368': '唐棣屬',
#  '8887716': '萌島|曼島',
#  '15264010': '四四拍子',
#  '7094731': '民謠',
#  '13734992': '公因數',
#  '12613285': '沼萍|水鱉科水鱉屬植物',
#  '9160968': '維拉|萬那杜首都',
#  '1946827': '腹足綱軟體動物',
#  '2888817': '土釘|角釘|無頭釘',
#  '14647722': '諾',
#  '7205104': '不|非',
#  '14614594': '亞磷酸',
#  '8761697': '雪蘭',
#  '4023695': '雞尾酒盆',
#  '3993053': '小便斗',
#  '2293352': '麥蛾',
#  '375625': '聚焦',
#  '3892178': '席紋地面|鑲木地板',
#  '1728445': '雷蛇',
#  '1269161': '阿金庫爾戰役',
#  '7689624': '香橙土司|橘香法式土司',
#  '14545215': '肌肉彈性',
#  '8936833': '馬賽市',
#  '14405061': '憂鬱|沮喪',
#  '2449699': '灰鼬鼠',
#  '10703905': '提出口供者|提供書面證供者|證人',
#  '12667406': '茜草屬常綠樹',
#  '8585540': '領域',
#  '14730105': '澱粉體|澱粉質',
#  '15054862': '澱粉質食物',
#  '5952678': '迷信',
#  '340192': '超車',
#  '2484473': '亞非猴|舊世界猴',
#  '14164341': '先天型貧血',
#  '8259753': '美國聯邦黨',
#  '7851926': '加工乳酪',
#  '12258380': '錫杖花科',
#  '10209731': '保險經紀人',
#  '6735922': '傳聞的證據',
#  '5621178': '狡詐|狡猾',
#  '7918879': '酒中加入糖水及香料之飲品|托地|托地酒|威士忌加熱水|香甜熱酒',
#  '14295140': '夾痛|捏痛',
#  '7417405': '緊急事件|事變',
#  '14409371': '困厄匱乏之境|窮苦|困苦',
#  '88725': '扣留|逮捕',
#  '357275': '捏|掐',
#  '842281': '咬',
#  '3905208': '窺視孔|窺孔',
#  '1259211': '有牌而不跟',
#  '14924602': '玉|翡翠',
#  '9772930': '蕩婦|淫婦',
#  '2382204': '駑馬|老馬',
#  '182435': '普選|大選',
#  '12097396': '白球樹|香料植物',
#  '12677841': '珊瑚莓',
#  '7027090': '輕鬆滑稽的小歌劇|滑稽歌劇|小歌劇',
#  '8913434': '伊拉克',
#  '11659627': '竹柏屬植物',
#  '6010583': '慣性座標|慣性參照系|慣性座標系',
#  '9965985': '驗屍官|法醫',
#  '8983413': '克拉科夫',
#  '2967294': '毯製的手提包',
#  '13104059': '樹木|樹',
#  '13912260': '樹狀圖|世系圖',
#  '11729860': '風信子花',
#  '12329020': '紫薇屬',
#  '3380867': '鞋襪|鞋子',
#  '12646950': '桂櫻',
#  '1850192': '巨頭鴨',
#  '7710007': '茄科蔬菜|茄屬植物',
#  '2783035': '圓扁鐵鎚',
#  '7029088': '信號曲|表示廣播開始的信號音',
#  '7028964': '主題曲',
#  '3347191': '火船',
#  '12764703': '漆樹科巴西乳香|胡椒樹|美洲中南部|加那利群島和中國熱帶和溫帶地區所產的常綠灌木和喬木',
#  '2499022': '狐猿',
#  '10144338': '離婚男子',
#  '96720': '搜救行動',
#  '8403082': '使節團|外交代表團',
#  '594260': '公使館|使節的職位|使館',
#  '2092339': '威瑪狗',
#  '14222685': '因陽光曝曬所產生的皮膚病',
#  '11340992': '梭羅',
#  '5496261': '海馬',
#  '1456631': '海馬屬',
#  '13176523': '星蕨屬',
#  '6902362': '公式翻譯語言|計算機語言',
#  '2577952': '短吻絲鱍',
#  '3953416': '祭祀地',
#  '7728585': '菜豆|四季豆|敏豆|雲豆',
#  '8750612': '哈瓦那|古巴首都',
#  '8684572': '馬上長矛比武場',
#  '7904293': '梅子白蘭地',
#  '2014524': '叫鶴',
#  '12306270': '美國西南方梣木',
#  '6492811': '郵寄名單',
#  '4137773': '衛星接收器',
#  '2325211': '棉尾兔屬',
#  '15245829': '場合|時機',
#  '9179264': '原因|事端',
#  '7447261': '場合|事件',
#  '7416714': '特殊的大事或儀式|特殊事件',
#  '14485064': '機會|時機',
#  '354583': '緩和|減輕',
#  '12255452': '蓋裂寄生科|加州和墨西哥一科寄生的肉質草本植物|缺乏綠葉有頭狀花序的小花的',
#  '1561318': '舊大陸鴝屬鳥類如黃尾鴝',
#  '8998853': '摩加迪休|索馬利亞首都',
#  '6345131': '欄外標題',
#  '2445715': '臭鼬',
#  '14275240': '擦傷',
#  '13099586': '腫脹',
#  '4915866': '厚臉皮',
#  '7548978': '憤慨|憤恨',
#  '14184390': '擦傷',
#  '114431': '拉|拖',
#  '9396712': '北極星',
#  '7069210': '口才|談鋒|雄辯',
#  '7607027': '蛋白小甜酥餅',
#  '2349847': '墨西哥棘小囊鼠',
#  '203649': '拒絕|冷淡的拒絕',
#  '11997409': '一種常見的多年生植物|廣泛分佈在美國東部及南部|有下垂的粉紅花和厚的根生葉|形狀像獅掌',
#  '2428842': '藏羚',
#  '10658501': '飼養員',
#  '4125257': '貴重物品存放處|保險倉庫|貴重物品保管處',
#  '13459322': '防禦反應',
#  '10979887': '巴爾巴羅薩|腓特烈一世',
#  '9989168': '小姐|單身女子|女孩',
#  '9784306': '過敏症專治醫師|過敏症專治',
#  '8365484': '國家資本主義',
#  '10174589': '雄心大志的人',
#  '4826771': '虔敬|虔誠',
#  '10546062': '竊賊|盜賊',
#  '2552171': '刺鰭魚',
#  '12385566': '木犀草',
#  '11874081': '黃水菫',
#  '1386494': '原生生物界',
#  '816841': '慣性導引',
#  '4115906': '上桅支索',
#  '12259615': '白雪紅花|某些分類中置於鹿蹄草科中',
#  '12309403': '桂花屬',
#  '7432034': '無線電雜音',
#  '1055360': '旅居|逗留',
#  '12866824': '風輪菜屬植物',
#  '14472624': '粗陋|未加工',
#  '2038010': '北方瓣蹼鷸屬',
#  '2113892': '大型貴賓狗|大型獅子狗',
#  '1880813': '袋鼠',
#  '12599435': '大車前草',
#  '9978566': '誘騙別人去當水手的人',
#  '12463322': '黑藥花科|某些分類中是由百合科細分出來但未被廣泛接受|此科包含肺筋草屬|沼澤日光蘭及藜蘆屬',
#  '7050952': '民歌|民謠',
#  '6932879': '拉祜語',
#  '12695760': '楝屬',
#  '14847810': '不飽和脂肪酸',
#  '12890265': '水苦檟屬之植物',
#  '4527310': '流量計',
#  '4074482': '補救方法|治療|補救',
#  '14555790': '雪盲症',
#  '12654659': '有長型黑莓的美洲黑刺莓',
#  '11966617': '加拿大蓬|飛蓬屬植物|生長於奧勒岡州到加州南部海岸',
#  '7026239': '室內樂',
#  '12879719': '美洲西部一屬多年生植物火焰草|會寄生在草根上',
#  '14651708': '鏷',
#  '1425983': '肉孢子蟲|目前對其所知不多|為一種寄生於脊椎動物肌肉中之寄生蟲',
#  '9991026': '講究修飾的人|紈褲子弟|好打扮的人',
#  '10588357': '王子|族長|酋長',
#  '13186200': '狗脊蕨屬',
#  '4557308': '水漆',
#  '9734885': '土耳其人',
#  '2286425': '棕尾毒蛾',
#  '12866002': '鼠尾草屬一種舊大陸高大的多年生鼠尾草|有紫藍色花|通常生長在寬闊的草地上',
#  '394803': '剝去|剝離',
#  '43195': '發現',
#  '3510487': '槓桿|扁擔',
#  '4788332': '過於講究|矯揉造作',
#  '10403366': '宴會女郎|派對女郎',
#  '13178284': '一種石葦屬植物',
#  '10201535': '騙子',
#  '9765278': '演員',
#  '3065063': '齒軌鐵路',
#  '6471737': '憑照|許可證',
#  '6522501': '租約',
#  '2477516': '粗壯南方古猿舊分類',
#  '10371741': '高級船員',
#  '12359734': '秋海棠科',
#  '11692108': '萼狀總苞|副萼',
#  '11962667': '漏盧花',
#  '5089612': '瑰寶|珍品',
#  '3240327': '油孔鑽頭|油井鑽頭',
#  '2247076': '白粉蝨屬',
#  '13726947': '英國熱量單位',
#  '2892948': '指虎',
#  '2835271': '雙人腳踏車|雙座腳踏車',
#  '7955726': '租地人|房客|佃農',
#  '12015221': '松脂植物',
#  '11973341': '松香草|向日葵科植物',
#  '6703213': '教育博士',
#  '2078436': '加洲海獅屬',
#  '6544432': '遺囑驗證文件|遺囑查訖證',
#  '3936269': '樁',
#  '13963032': '絕種',
#  '4553703': '洗臉台',
#  '4553920': '盥洗室|洗手間',
#  '10698241': '電視福音傳道人|電視佈道家',
#  '14367649': '陰囊象皮病',
#  '8806617': '義大利東北部地區',
#  '9367203': '必需品',
#  '14884963': '甘油酸',
#  '2314001': '外肛苔蘚蟲門動物',
#  '716777': '活體解剖',
#  '13376426': '信用卡',
#  '1799540': '官鳥屬|鳳冠雉屬',
#  '2595339': '銀色鼓魚',
#  '2566489': '白鱸',
#  '11894558': '野生蘿菔',
#  '2488415': '長尾猴',
#  '10011486': '寫日記的人',
#  '1642391': '墨西哥蛙',
#  '1605630': '鷹|隼',
#  '10162644': '鷹派人物|鷹派成員',
#  '3288742': '英國管',
#  '2085118': '野狗',
#  '14850948': '醋酸醚|醋酸乙酯',
#  '493031': '蒙特牌戲',
#  '2110627': '猴面犬',
#  '15151641': '青春時期|全盛時期',
#  '14948055': '古綠石|蛇雜紋石',
#  '4252653': '螺旋式除雪機|吹雪機',
#  '7255791': '超自然溝通',
#  '4710127': '嚴酷|艱難',
#  '4643099': '嚴酷|刻薄',
#  '3673450': '女用內衣',
#  '1847253': '潛水鴨|潛鴨',
#  '617601': '細木工|細木匠業',
#  '2381261': '毛色晦暗褐灰的馬',
#  '4973110': '暗褐色',
#  '7475242': '對方發球而己方取勝局',
#  '10581464': '連續殺人犯',
#  '12293419': '龍膽屬',
#  '10262343': '對愛情不專一的女子',
#  '8619949': '公路收費站廣場|收費廣場',
#  '1499732': '北美舌形花',
#  '9481036': '蟲孔|蛀洞',
#  '11957514': '大麗花|一種由墨西哥野花發展出來的觀賞用植物',
#  '9447047': '麥哲倫海峽',
#  '12525975': '草合歡屬',
#  '8308039': '委員集會',
#  '1564217': '金冠鷦鷯',
#  '14593671': '合成樹脂|壓克力|丙烯酸樹脂',
#  '11845019': '頂花球屬',
#  '10744544': '無業游民|乞丐|流浪者',
#  '12240715': '南燭屬',
#  '4635953': '倦怠|無力',
#  '14014990': '昏睡|遲鈍',
#  '14842847': '火',
#  '3343560': '電暖爐|煤氣爐|爐火',
#  '986938': '發射|發砲|射擊',
#  '6711159': '抨擊|辱罵',
#  '7420435': '磨難',
#  '13480848': '火焰|炎焰',
#  '7302836': '大火|火災|火',
#  '7481375': '熱烈|熱心|熱情',
#  '10726031': '異性服裝癖者|好穿異性服裝的|異性模仿癖者',
#  '8357647': '外交部門',
#  '10777894': '偽善者|偽君子',
#  '10749123': '老將|老手|老練的人',
#  '234892': '反轉',
#  '7411160': '逆轉|反轉',
#  '5789808': '反轉|倒轉',
#  '346693': '轉向|反轉',
#  '1185981': '翻案',
#  '339776': '翻轉|轉換',
#  '7475870': '不幸',
#  '163406': '變卦',
#  '4494762': '無內胎輪胎',
#  '2790823': '有刺鐵絲|有剌鐵絲網|倒鉤鐵絲網',
#  '5155476': '智謀',
#  '5633860': '有機智|應變能力|足智多謀',
#  '3786417': '嗎啡|止痛劑|麻醉劑',
#  '5722427': '觸覺',
#  '5262534': '鬚|濃密的八字鬍',
#  '2269657': '石蠶|蠐螬',
#  '7004057': '心電圖',
#  '4384910': '尾燈',
#  '66216': '失敗',
#  '2964634': '載貨空間',
#  '6928047': '察克台語',
#  '7285403': '遭遇|經歷',
#  '5984584': '遭遇|經歷|經驗',
#  '5758059': '經驗',
#  '9081560': '波伊西|愛德荷州首府',
#  '12866162': '鼠尾草屬',
#  '3855908': '最下層甲板|最下甲板',
#  '5120310': '重複|多餘',
#  '7219923': '進度報告',
#  '1679178': '無耳蜥蜴',
#  '12428412': '豹斑百合',
#  '12427184': '虎皮百合',
#  '12416073': '豹斑百合',
#  '2314717': '環口動物門',
#  '12537437': '鵲豆屬',
#  '210940': '漸淡',
#  '12944238': '繖形科豆蔻流水草',
#  '1073241': '姑息|寬容|矯寵',
#  '12258885': '水晶蘭',
#  '3253886': '厚布製的大背袋',
#  '1608934': '鳶屬的一種',
#  '12374238': '木犀花屬',
#  '8352613': '售貨員',
#  '10014658': '善用手腕之人|圓滑之人',
#  '10013927': '外交官',
#  '12371704': '亞洲東部觀賞用的藤本植物|有黃色可食花朵|葉有銀白色紋路|如葛棗獼猴桃',
#  '6890846': '炫耀|誇示',
#  '1004072': '分開',
#  '4749709': '不一致',
#  '7366289': '偏移|偏差',
#  '9217230': '沙灘|海濱|海灘',
#  '3457451': '護痙套|護脛甲',
#  '1826223': '佛法僧科',
#  '845523': '性交',
#  '2917377': '手提音響|手提式揚聲機|手提式擴音器',
#  '9426621': '粗皮|鱗狀外皮',
#  '9425607': '鱗癬|皮屑',
#  '3322940': '農機',
#  '10548227': '售貨員',
#  '4017807': '巡邏魚雷艇|魚雷哨艇',
#  '13228194': '金星蕨科的一種附生或陸生蕨類',
#  '1382273': '密螺旋體',
#  '12768933': '俄亥俄七葉樹',
#  '1421164': '隱藻綱|一種棕綠色之原生藻',
#  '9786338': '畢業生',
#  '11492833': '同質多形',
#  '11491816': '多型性|多型現象',
#  '1675722': '條狀壁虎',
#  '87073': '搶先佔據|搶先佔有',
#  '5700087': '凝神|全神貫注|專心一意',
#  '1452051': '隱燈眼鯛屬|燈眼魚科之一屬',
#  '9929577': '臨床醫生',
#  '15269331': '軌到軌搜尋時間',
#  '6485933': '議程|討論事項',
#  '2519862': '密西西比藍色鯰魚',
#  '1662274': '龜鱉目',
#  '1663659': '綠蠵龜',
#  '13695420': '蘇丹鎊',
#  '2971940': '唱頭|電唱頭',
#  '10432053': '偶然結識的人|勾搭上的人',
#  '3930777': '提神',
#  '5061003': '加速',
#  '319176': '載',
#  '6547832': '逮補令',
#  '3930630': '敞篷小貨車',
#  '1016201': '收拾',
#  '4450465': '唱頭|電唱頭',
#  '10442232': '沈重行走的人|拖著沉重腳步行走的人',
#  '12687957': '海神葵',
#  '1533339': '金絲雀',
#  '5567381': '食指',
#  '11870607': '香雪球屬',
#  '7434102': '扭彎|失真|彎曲',
#  '8581503': '常去之處',
#  '12919195': '野生大戟|美國常見多年生大戟|有似白色花瓣的顯眼苞片',
#  '12182414': '花葵|一種分佈廣的草本或軟木樹狀灌木',
#  '7538395': '消沉|失望|沮喪',
#  '10087574': '文件編檔員|文件裝釘員',
#  '7442439': '反旋轉|迴旋|反旋轉',
#  '12554029': '西印度群島紅豆屬喬木|複葉和種子較小',
#  '13825664': '信號噪聲比',
#  '9395086': '極小的行星|微星',
#  '232863': '解約',
#  '8578517': '海底生物|海底|湖底',
#  '7639069': '甜甜圈',
#  '1027662': '古羅馬人口普查後所舉行的儀式|驅邪儀式',
#  '15204907': '五年時間',
#  '4604806': '蝸齒輪',
#  '8366440': '國家社會主義',
#  '591858': '管理者的職位',
#  '4889162': '充紳士氣派|勢利眼',
#  '6890470': '炫耀|誇耀',
#  '6856884': '喇叭聲',
#  '6890254': '炫耀|誇耀',
#  '6890373': '花腔',
#  '1402169': '褐藻門',
#  '11768505': '南非一種中型灌木',
#  '1697457': '尼羅河鱷魚',
#  '6421844': '習俗',
#  '1874434': '有袋動物',
#  '1369484': '傷寒桿菌',
#  '8939201': '里維埃拉海岸地區',
#  '11973749': '波狀膠草',
#  '3933183': '皮塊',
#  '3544143': '砂漏',
#  '7390400': '砰|砰的一聲',
#  '3124043': '牛仔靴',
#  '7086972': '強拍',
#  '6522119': '射倖契約|僥倖契約',
#  '2487675': '印度頭上有似冠的猴子',
#  '12549192': '蛇麻車軸草',
#  '9216442': '孟加拉灣',
#  '7704579': '蕎麥片|蕎麥粥',
#  '3708425': '磁石發電機|磁發電機',
#  '14650137': '鈽 239',
#  '13118707': '半灌木',
#  '7320302': '出生|誕生',
#  '6192908': '基督誕生',
#  '1279866': '格拉尼卡斯之役',
#  '10399130': '賣免罪符者|中世紀的賣贖罪券者',
#  '10033082': '服裝管理員',
#  '3237340': '有架子的櫥櫃',
#  '3015254': '櫃子',
#  '7031636': '旋律',
#  '6384269': '詩|長詩中的篇章|篇章',
#  '14218158': '葉震病|松柏科植物的疾病會造成真葉掉落',
#  '11455092': '驟發山洪',
#  '14697485': '砂石',
#  '6716234': '嘲笑|嘲弄',
#  '9518145': '艾蕾斯吉卡兒',
#  '9034550': '坦桑尼亞|坦尚尼亞',
#  '1238424': '合併',
#  '381680': '統一|合併',
#  '12144742': '甜玉米植物',
#  '2820798': '療養院|瘋人院',
#  '10533013': '競爭對手|競爭者',
#  '6714184': '夫妻間秘密談話',
#  '11687071': '配子體',
#  '2218235': '姬蜂科',
#  '3348868': '藥室',
#  '1570549': '黃喉地鶯',
#  '5348884': '唇動脈',
#  '4733347': '冒泡|沸騰',
#  '5988743': '不可知論',
#  '1722998': '翼龍|翼手龍|翼指龍',
#  '9774783': '提倡者|倡導者|鼓吹者',
#  '9775663': '律師',
#  '9294877': '巖穴|岩穴',
#  ...}

# %%
ec_link ={}
for line in open("/Users/7ckung/Desktop/Lab2/ec.link.txt"):
    en = line.strip().split("\t")[1]
    ch = line.strip().split("\t")[2].replace('->', '')
    ec_link[str(ch)] = str(en)

# %%
c=0
for sense in target_synsets:
    offset = sense[1].offset()
    ch = wn_ec[str(offset)]
    ch_l = []
    if '|' in ch:
        ch_l = ch.split('|')
    else:
        ch_l.append(ch)
    find = True
    for ch_item in ch_l:
        if ch_item in ec_link:
            try:
                page = wikipedia.page(ec_link[str(ch_item)])
                print(page.url)
                c+=1
                             
            except:
                find = False

            if find:
                break
        if not find:
            print('there is no chinese info for this page')
c
# Out:
# https://en.wikipedia.org/wiki/Factory
# https://en.wikipedia.org/wiki/Plant
# https://en.wikipedia.org/wiki/Taste
# there is no chinese info for this page
# there is no chinese info for this page
# there is no chinese info for this page
# there is no chinese info for this page
# there is no chinese info for this page
# there is no chinese info for this page
# there is no chinese info for this page
# https://en.wikipedia.org/wiki/Taste
# https://en.wikipedia.org/wiki/Astronomical_object
# https://en.wikipedia.org/wiki/Asterisk
# there is no chinese info for this page
# there is no chinese info for this page
# there is no chinese info for this page
# there is no chinese info for this page
# there is no chinese info for this page
# https://en.wikipedia.org/wiki/Bowing
# https://en.wikipedia.org/wiki/Bowing
# there is no chinese info for this page
# there is no chinese info for this page
# there is no chinese info for this page
# there is no chinese info for this page
# there is no chinese info for this page
# there is no chinese info for this page
# there is no chinese info for this page
# https://en.wikipedia.org/wiki/Interest
# there is no chinese info for this page
# https://en.wikipedia.org/wiki/Shareholder
# https://en.wikipedia.org/wiki/Hobby
# https://en.wikipedia.org/wiki/Problem_solving
# https://en.wikipedia.org/wiki/Problem_solving
# https://en.wikipedia.org/wiki/Promise
# https://en.wikipedia.org/wiki/Duty
# 15

# %% [markdown]
# # An example of wordnet synset

# %%
for synset in wn.synsets('plant', pos='n'):
    print(synset)
    print(synset.definition())
    examples = synset.examples()
    if len(examples) > 0:
        print(examples[0])
    else:
        print("No example")
    print(synset.lemmas())
    print("#"*70)
# Out:
# Synset('plant.n.01')
# buildings for carrying on industrial labor
# they built a large plant to manufacture automobiles
# [Lemma('plant.n.01.plant'), Lemma('plant.n.01.works'), Lemma('plant.n.01.industrial_plant')]
# ######################################################################
# Synset('plant.n.02')
# (botany) a living organism lacking the power of locomotion
# No example
# [Lemma('plant.n.02.plant'), Lemma('plant.n.02.flora'), Lemma('plant.n.02.plant_life')]
# ######################################################################
# Synset('plant.n.03')
# an actor situated in the audience whose acting is rehearsed but seems spontaneous to the audience
# No example
# [Lemma('plant.n.03.plant')]
# ######################################################################
# Synset('plant.n.04')
# something planted secretly for discovery by another
# the police used a plant to trick the thieves
# [Lemma('plant.n.04.plant')]
# ######################################################################

# %%
#output wiki page
page = wikipedia.page("Apple")
print(page.url)

#output wiki page by id in ec.link.txt
page = wikipedia.page(title=None, pageid=12)
print(page.url)

#reference https://wikipedia.readthedocs.io/en/latest/code.html
# Out:
# https://en.wikipedia.org/wiki/Apple
# https://en.wikipedia.org/wiki/Anarchism
